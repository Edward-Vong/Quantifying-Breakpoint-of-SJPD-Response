# %% [markdown]
# # 03c. EDA - Call Profiles

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pathlib

PROCESSED_DATA_PATH = pathlib.Path("data/processed")
data_file = list(PROCESSED_DATA_PATH.glob("*_processed.parquet"))[0]
df = pd.read_parquet(data_file)

print(f"Loaded {len(df):,} records.")
# Out:
# Loaded 3,077,538 records.

# %% [markdown]
# ## 1. Top Call Types
# What are the most frequent reasons for dispatch?

# %%
top_types = df["CALL_TYPE"].value_counts().head(20)

plt.figure(figsize=(10, 8))
top_types.sort_values().plot(kind="barh", color="skyblue")
plt.title("Top 20 Call Types")
plt.xlabel("Frequency")
plt.show()

# %% [markdown]
# ## 2. Final Dispositions
# How are these calls resolved? We look at the share of reports taken vs. cancellations.

# %%
dispo_counts = df["FINAL_DISPO"].value_counts().head(15)

plt.figure(figsize=(10, 6))
dispo_counts.plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribution of Top 15 Final Dispositions")
plt.ylabel("")
plt.show()

display(dispo_counts)
# Out:
# FINAL_DISPO
# No report required; dispatch r                  736278
# No report required; dispatch record only        628507
# Canceled                                        535983
# Report taken                                    382917
# No Disposition                                  123119
# Gone on Arrival/unable to loca                  105631
# No Response                                      64690
# Arrest Made                                      61677
# Gone on Arrival/unable to locate                 60687
# Supplemental report taken                        52099
# Traffic Citation Issued, Non-H                   51569
# Unfounded event                                  39465
# Traffic Citation Issued, Hazar                   38483
# Traffic Citation Issued, Hazardous Violation     32726
# Criminal Citation                                31816
# Name: count, dtype: int64
